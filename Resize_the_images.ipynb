# %% [markdown]
# <a href="https://colab.research.google.com/github/SukhmanpreetKaurManes/Miniproject-24-Resize-images/blob/main/Resize_the_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install bing-image-downloader

# %%
import os
import shutil
import cv2
from bing_image_downloader import downloader

# %%
# Step 1: Create the input_images folder
input_folder = 'input_images'
os.makedirs(input_folder, exist_ok=True)

# Step 2: Download 50 images into input_images/search_keyword/
search_keyword = "cow"  # Change this to any search term
downloader.download(search_keyword, limit=50, output_dir=input_folder, adult_filter_off=True)

# Step 3: Move all images from subfolder to input_images/
subfolder_path = os.path.join(input_folder, search_keyword)

for file in os.listdir(subfolder_path):
    if file.lower().endswith(('.jpg', '.jpeg', '.png')):
        shutil.move(os.path.join(subfolder_path, file), os.path.join(input_folder, file))

# Remove the empty keyword-named folder
os.rmdir(subfolder_path)

print(f"✅ Downloaded and moved 100 '{search_keyword}' images to '{input_folder}'")

# Step 4: Resize all images to 50% and save to 'resized_images'
output_folder = 'resized_images'
os.makedirs(output_folder, exist_ok=True)

for file in os.listdir(input_folder):
    if file.lower().endswith(('.jpg', '.jpeg', '.png')):
        img_path = os.path.join(input_folder, file)
        img = cv2.imread(img_path)

        if img is None:
            print(f"⚠️ Skipped unreadable image: {file}")
            continue

        # Resize to 50%
        height, width = img.shape[:2] #get image height and width
        resized = cv2.resize(img, (width // 2, height // 2))

        # Save resized image
        cv2.imwrite(os.path.join(output_folder, file), resized)

print(f"✅ All images resized to 50% and saved in '{output_folder}'")
# Out:
# [%] Downloading Images to /content/input_images/cow
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 87 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/0/05/Cow-bw.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://upload.wikimedia.org/wikipedia/commons/0/0c/Cow_female_black_white.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://images.pexels.com/photos/51311/cow-calf-cattle-stock-51311.jpeg?cs=srgb&amp;dl=pexels-pixabay-51311.jpg&amp;fm=jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://media.4-paws.org/3/e/5/6/3e56785d2a08c27be3ca72082c20fd0a4545586d/VIER PFOTEN_2015-04-27_010-1927x1333-1920x1328.jpg
# [!] Issue getting: https://media.4-paws.org/3/e/5/6/3e56785d2a08c27be3ca72082c20fd0a4545586d/VIER PFOTEN_2015-04-27_010-1927x1333-1920x1328.jpg
# ...

# %%
print("Original:", img.shape)
print("Resized:", resized.shape)
